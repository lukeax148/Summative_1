# %% [markdown]
# # Python Analysis Data Product

# %% [markdown]
# First i imported the libraries that i will be using to complete this python analysis data product project

# %%
#!pip install wbgapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 70.5 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import wbgapi as wb 
import pandas as pd

# %% [markdown]
# Next i will use the wbgapi library to pull data from the World Bank Data API and the pandas library to store the data in a dataframe.

# %%
def GDP_data(country, start_date, end_date):
    '''The GDP_data function will pull current Gross Domestic product data from the World Bank Data API
     depending on the country or countries selected (e.g. ['USA','CHN','GBR']) 
     and the start and end of the time series in years (e.g. 2000, 2010).
     
     >>> country = (['USA','GBR','CHN'])
     >>> x = GDP_data(country,2010,2022)  

     x.index.unique() = country
     
     
     '''
    data = wb.data.DataFrame('NY.GDP.MKTP.CN', country, range(start_date, end_date), labels=True)
    return data

# %% [markdown]
# Next I use the help() function to provide more information about the GDP-data function and confirming whether or not the Docstring is working correctly

# %%
help(GDP_data)
# Out:
# Help on function GDP_data in module __main__:
#
# GDP_data(country, start_date, end_date)
#     The GDP_data function will pull current Gross Domestic product data from the World Bank Data API
#     depending on the country or countries selected (e.g. ['USA','CHN','GBR'])
#     and the start and end of the time series in years (e.g. 2000, 2010).
#
#     >>> country = (['USA','GBR','CHN'])
#     >>> x = GDP_data(country,2010,2022)
#
#     x.index.unique() = country

# %% [markdown]
# Next i have tested the GDP_data function by calling it in reference to the following contries; United States of America, Great Britian and China. The start and end date selected will be 2010 and 2022 respectively.

# %%
x= GDP_data(['USA','GBR','CHN'],2010,2022)
x.head(5)
# Out:
#                 Country        YR2010        YR2011        YR2012  \
# economy
# CHN               China  4.121193e+13  4.879402e+13  5.385800e+13
# GBR      United Kingdom  1.608553e+12  1.662590e+12  1.713715e+12
# USA       United States  1.504896e+13  1.559973e+13  1.625397e+13
#
#                YR2013        YR2014        YR2015        YR2016        YR2017  \
# economy
# CHN      5.929632e+13  6.435631e+13  6.888582e+13  7.463951e+13  8.320359e+13
# GBR      1.781361e+12  1.862514e+12  1.916451e+12  1.991645e+12  2.082482e+12
# USA      1.684319e+13  1.755068e+13  1.820602e+13  1.869511e+13  1.947734e+13
#
#                YR2018        YR2019        YR2020        YR2021
# economy
# CHN      9.192811e+13  9.865152e+13  1.013567e+14  1.149237e+14
# GBR      2.152304e+12  2.233921e+12  2.104288e+12  2.284079e+12
# USA      2.053306e+13  2.138098e+13  2.106047e+13  2.331508e+13

# %% [markdown]
# Next i imported the matplotlib and seasborn libraries to create visualisations of the World Bank Data

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as pe
import doctest

# %% [markdown]
# Next i have used the doctest library to test the GDP_data function

# %%
doctest.testmod(verbose=True)
# Out:
# Trying:
#     country = (['USA','GBR','CHN'])
# Expecting nothing
# ok
# Trying:
#     x = GDP_data(country,2010,2022)
# Expecting nothing
# ok
# 17 items had no tests:
#     __main__
#     __main__.DeepnoteChart
#     __main__.DeepnoteChart.__init__
#     __main__.DeepnoteChart._repr_mimebundle_
#     __main__._deepnote_add_formatters
#     __main__._deepnote_browse_df
#     __main__._deepnote_execute_post_start_hooks
#     __main__._deepnote_execute_sql
#     __main__._deepnote_execute_sql_with_connection_json
#     __main__._deepnote_export_df
#     __main__._deepnote_get_var_list
#     __main__._deepnote_initialize_imports
#     __main__._deepnote_persist_notebook_session
#     __main__._deepnote_restore_notebook_session
#     __main__._deepnote_set_integration_env
#     __main__._set_notebook_path
#     __main__.page_printer
# 1 items passed all tests:
#    2 tests in __main__.GDP_data
# 2 tests in 18 items.
# 2 passed and 0 failed.
# Test passed.
# ...

# %% [markdown]
# Lastly i created a function to create a graphical visualisation of the World Bank Data retreived from the GDP_data function

# %%
def create_graph(data):
    data = data.set_index('Country').transpose()
    graph = sns.lineplot(data=data,  legend=True, palette='Set1')
    plt.setp(graph.get_xticklabels(), rotation=90)
    return graph

# %%
create_graph(x)
# Out:
# <AxesSubplot: >

# %%
y = GDP_data(['AUS','DEU'],2012,2023)
create_graph(y)
# Out:
# <AxesSubplot: >

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5a5b1da2-9b60-45f8-aff2-0e0e69a20999' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
